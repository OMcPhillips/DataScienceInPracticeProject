# %%
import networkx as nx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
athletes = pd.read_csv('athlete_events.csv')
athletes.shape
# Out:
# (271116, 15)

# %%
GDP = pd.read_excel('w_gdp.xls', skiprows=3)
GDP.shape
# Out:
# (219, 62)

# %%
noc = pd.read_csv('noc_regions.csv')
noc.shape
# Out:
# (230, 3)

# %%
noc.drop(['notes'], axis=1, inplace=True)

# %%
GDP.drop(['Indicator Name', 'Indicator Code'], axis=1, inplace=True)

# %%
#new_header = GDP.iloc[2] 
#GDP = GDP[3:] 
#GDP.columns = new_header

# %%
GDP.head(3)
# Out:
#   Country Name Country Code          1960          1961          1962  \
# 0  Afghanistan          AFG  5.377778e+08  5.488889e+08  5.466667e+08
# 1      Albania          ALB           NaN           NaN           NaN
# 2      Algeria          DZA  2.723649e+09  2.434777e+09  2.001469e+09
#
#            1963          1964          1965          1966          1967  ...  \
# 0  7.511112e+08  8.000000e+08  1.006667e+09  1.400000e+09  1.673333e+09  ...
# 1           NaN           NaN           NaN           NaN           NaN  ...
# 2  2.703015e+09  2.909352e+09  3.136259e+09  3.039835e+09  3.370843e+09  ...
#
#            2008          2009          2010          2011          2012  \
# 0  1.019053e+10  1.248694e+10  1.593680e+10  1.793024e+10  2.053654e+10
# 1  1.288135e+10  1.204421e+10  1.192695e+10  1.289087e+10  1.231978e+10
# 2  1.710007e+11  1.372110e+11  1.612073e+11  2.000191e+11  2.090590e+11
#
#            2013          2014          2015          2016  2017
# 0  2.004633e+10  2.005019e+10  1.921556e+10  1.946902e+10   NaN
# 1  1.277628e+10  1.322824e+10  1.133526e+10  1.186387e+10   NaN
# 2  2.097550e+11  2.138100e+11  1.658743e+11  1.590491e+11   NaN
#
# [3 rows x 60 columns]

# %%
#GDP.reset_index(drop =True).head(3)

# %%
print (GDP.columns.tolist())
# Out:
# ['Country Name', 'Country Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017']

# %%
GDP = pd.melt(GDP, id_vars = ['Country Name', 'Country Code'], var_name = 'Year', value_name = 'GDP')

# %%
GDP['Year'] = pd.to_numeric(GDP['Year'])

# %%
GDP.head(10)
# Out:
#           Country Name Country Code  Year           GDP
# 0          Afghanistan          AFG  1960  5.377778e+08
# 1              Albania          ALB  1960           NaN
# 2              Algeria          DZA  1960  2.723649e+09
# 3       American Samoa          ASM  1960           NaN
# 4              Andorra          AND  1960           NaN
# 5               Angola          AGO  1960           NaN
# 6  Antigua and Barbuda          ATG  1960           NaN
# 7            Argentina          ARG  1960           NaN
# 8              Armenia          ARM  1960           NaN
# 9                Aruba          ABW  1960           NaN

# %%
athletes.head(7)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season         City          Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer       London           Judo
# 2  DEN  1920 Summer  1920  Summer    Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter      Calgary  Speed Skating
# 5  NED  1988 Winter  1988  Winter      Calgary  Speed Skating
# 6  NED  1992 Winter  1992  Winter  Albertville  Speed Skating
#
#                                 Event Medal
# 0         Basketball Men's Basketball   NaN
# 1        Judo Men's Extra-Lightweight   NaN
# 2             Football Men's Football   NaN
# 3         Tug-Of-War Men's Tug-Of-War  Gold
# 4    Speed Skating Women's 500 metres   NaN
# 5  Speed Skating Women's 1,000 metres   NaN
# 6    Speed Skating Women's 500 metres   NaN

# %%
athleteNOC = athletes.merge(noc, left_on='NOC', right_on='NOC', how='left')

# %%
athleteNOC.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region
# 0       Basketball Men's Basketball   NaN        China
# 1      Judo Men's Extra-Lightweight   NaN        China
# 2           Football Men's Football   NaN      Denmark
# 3       Tug-Of-War Men's Tug-Of-War  Gold      Denmark
# 4  Speed Skating Women's 500 metres   NaN  Netherlands

# %%
gdpAthlete = pd.merge(GDP, athleteNOC, left_on = ['Country Code', 'Year'], right_on = ['NOC', 'Year'], how='left')

# %%
gdpAthlete.drop(['ID', 'Team', 'Games', 'region'], axis=1, inplace=True)

# %%
gdpAthlete.sample(5)
# Out:
#        Country Name Country Code  Year           GDP                Name  Sex  \
# 50721         Spain          ESP  1984  1.716355e+11  Javier Reino Garca    M
# 129030       Poland          POL  2008  5.338158e+11      Agata Ewa Korc    F
# 54622        Brazil          BRA  1988  3.303974e+11   Tnia Mara Miranda    F
# 14133   Isle of Man          IMN  1966           NaN                 NaN  NaN
# 10001         Italy          ITA  1964  6.317542e+10   Giovanni Girgenti    M
#
#          Age  Height  Weight  NOC  Season         City      Sport  \
# 50721   21.0   195.0    94.0  ESP  Summer  Los Angeles   Handball
# 129030  22.0   175.0    58.0  POL  Summer      Beijing   Swimming
# 54622   30.0   160.0    50.0  BRA  Summer        Seoul  Athletics
# 14133    NaN     NaN     NaN  NaN     NaN          NaN        NaN
# 10001   21.0   165.0    57.0  ITA  Summer        Tokyo     Boxing
#
#                                          Event Medal
# 50721                  Handball Men's Handball   NaN
# 129030   Swimming Women's 100 metres Freestyle   NaN
# 54622   Athletics Women's 4 x 400 metres Relay   NaN
# 14133                                      NaN   NaN
# 10001               Boxing Men's Featherweight   NaN

# %%
gdpAthlete.shape
# Out:
# (163046, 15)

# %%
gdpAthlete = gdpAthlete[gdpAthlete['Name'].notna()]

# %%
gdpAthlete.shape
# Out:
# (151977, 15)

# %%
gdpAthlete['Medal'].fillna('DNW', inplace = True)

# %%
print(gdpAthlete.isnull().sum())
# Out:
# Country Name       0
# Country Code       0
# Year               0
# GDP             9752
# Name               0
# Sex                0
# Age              545
# Height          7432
# Weight          8104
# NOC                0
# Season             0
# City               0
# Sport              0
# Event              0
# Medal              0
# dtype: int64

# %%
gdpAthlete = gdpAthlete[gdpAthlete['GDP'].notna()]
gdpAthlete = gdpAthlete[gdpAthlete['Age'].notna()]
gdpAthlete = gdpAthlete[gdpAthlete['Weight'].notna()]
gdpAthlete = gdpAthlete[gdpAthlete['Height'].notna()]

# %%
print(gdpAthlete.isnull().sum())
# Out:
# Country Name    0
# Country Code    0
# Year            0
# GDP             0
# Name            0
# Sex             0
# Age             0
# Height          0
# Weight          0
# NOC             0
# Season          0
# City            0
# Sport           0
# Event           0
# Medal           0
# dtype: int64

# %%
gdpAthlete.shape
# Out:
# (133996, 15)

# %%
gdpAthlete.sample(5)
# Out:
#        Country Name Country Code  Year           GDP  \
# 90811         Japan          JPN  1998  4.032510e+12
# 152695    Australia          AUS  2016  1.204616e+12
# 138358       Brazil          BRA  2012  2.465189e+12
# 104951       France          FRA  2002  1.500338e+12
# 22981      Cameroon          CMR  1972  1.430951e+09
#
#                                  Name Sex   Age  Height  Weight  NOC  Season  \
# 90811                 Ryoko Takahashi   F  24.0   156.0    51.0  JPN  Winter
# 152695  Kenneth Maxwell "Ken" Wallace   M  33.0   190.0    90.0  AUS  Summer
# 138358   Paula Renata Marques Pequeno   F  30.0   184.0    74.0  BRA  Summer
# 104951                 Anthony Mortas   M  27.0   184.0    86.0  FRA  Winter
# 22981            Jean Bernard Djambou   M  25.0   172.0    69.0  CMR  Summer
#
#                   City       Sport                                     Event  \
# 90811           Nagano    Biathlon            Biathlon Women's 15 kilometres
# 152695  Rio de Janeiro    Canoeing  Canoeing Men's Kayak Fours, 1,000 metres
# 138358          London  Volleyball             Volleyball Women's Volleyball
# 104951  Salt Lake City  Ice Hockey               Ice Hockey Men's Ice Hockey
# 22981           Munich     Cycling       Cycling Men's Road Race, Individual
#
#        Medal
# 90811    DNW
# 152695   DNW
# 138358  Gold
# 104951   DNW
# 22981    DNW

# %%
gdpAthlete['Determining Year'] = gdpAthlete['Year'] - 4

# %%
gdpAthlete.head()
# Out:
#   Country Name Country Code  Year           GDP                     Name Sex  \
# 0  Afghanistan          AFG  1960  5.377778e+08     Sultan Mohammad Dost   M
# 1  Afghanistan          AFG  1960  5.377778e+08    Abdul Ghafar Ghafoori   M
# 2  Afghanistan          AFG  1960  5.377778e+08    Ghulam Mohiddin Gunga   M
# 3  Afghanistan          AFG  1960  5.377778e+08  Mohammad Ibrahim Kederi   M
# 4  Afghanistan          AFG  1960  5.377778e+08   Faiz Mohammad Khakshar   M
#
#     Age  Height  Weight  NOC  Season  City      Sport  \
# 0  28.0   168.0    73.0  AFG  Summer  Roma  Wrestling
# 1  22.0   172.0    70.0  AFG  Summer  Roma  Athletics
# 2  26.0   168.0    81.0  AFG  Summer  Roma  Wrestling
# 3  20.0   166.0    62.0  AFG  Summer  Roma  Wrestling
# 4  18.0   162.0    52.0  AFG  Summer  Roma  Wrestling
#
#                                           Event Medal  Determining Year
# 0       Wrestling Men's Welterweight, Freestyle   DNW              1956
# 1          Athletics Men's 4 x 100 metres Relay   DNW              1956
# 2  Wrestling Men's Light-Heavyweight, Freestyle   DNW              1956
# 3      Wrestling Men's Featherweight, Freestyle   DNW              1956
# 4          Wrestling Men's Flyweight, Freestyle   DNW              1956

# %%
determineDF = pd.merge(GDP, gdpAthlete, left_on = ['Country Code', 'Year'], right_on = ['NOC', 'Determining Year'], how='right')

# %%
print(determineDF.isnull().sum())
# Out:
# Country Name_x      4371
# Country Code_x      4371
# Year_x              4371
# GDP_x               6105
# Country Name_y         0
# Country Code_y         0
# Year_y                 0
# GDP_y                  0
# Name                   0
# Sex                    0
# Age                    0
# Height                 0
# Weight                 0
# NOC                    0
# Season                 0
# City                   0
# Sport                  0
# Event                  0
# Medal                  0
# Determining Year       0
# dtype: int64

# %%
determineDF.shape
# Out:
# (133996, 20)

# %%
determineDF.drop(['Country Name_x', 'Country Code_x', 'Year_x'], axis=1, inplace=True)

# %%
determineDF.head(5)
# Out:
#           GDP_x Country Name_y Country Code_y  Year_y         GDP_y  \
# 0  5.377778e+08    Afghanistan            AFG    1964  8.000000e+08
# 1  5.377778e+08    Afghanistan            AFG    1964  8.000000e+08
# 2           NaN      Argentina            ARG    1964  2.560525e+10
# 3           NaN      Argentina            ARG    1964  2.560525e+10
# 4           NaN      Argentina            ARG    1964  2.560525e+10
#
#                      Name Sex   Age  Height  Weight  NOC  Season   City  \
# 0       Mohammad Ebrahimi   M  26.0   160.0    63.0  AFG  Summer  Tokyo
# 1  Faiz Mohammad Khakshar   M  22.0   162.0    52.0  AFG  Summer  Tokyo
# 2         Hctor H. Acosta   M  30.0   180.0    81.0  ARG  Summer  Tokyo
# 3            Juan Aguilar   M  21.0   174.0    75.0  ARG  Summer  Tokyo
# 4       Abel Csar Almaraz   M  22.0   152.0    54.0  ARG  Summer  Tokyo
#
#        Sport                                         Event Medal  \
# 0  Wrestling      Wrestling Men's Featherweight, Freestyle   DNW
# 1  Wrestling          Wrestling Men's Flyweight, Freestyle   DNW
# 2    Cycling  Cycling Men's 100 kilometres Team Time Trial   DNW
# 3     Boxing                     Boxing Men's Middleweight   DNW
# 4     Boxing                     Boxing Men's Bantamweight   DNW
#
#    Determining Year
# 0              1960
# 1              1960
# 2              1960
# 3              1960
# 4              1960

# %%
determineDF.iloc[0]['GDP_y']
# Out:
# 800000044.4444444

# %%
determineDF = determineDF[determineDF['GDP_x'].notna()]

# %%
determineDF.head()
# Out:
#             GDP_x Country Name_y Country Code_y  Year_y         GDP_y  \
# 0    5.377778e+08    Afghanistan            AFG    1964  8.000000e+08
# 1    5.377778e+08    Afghanistan            AFG    1964  8.000000e+08
# 149  1.859335e+10      Australia            AUS    1964  2.378766e+10
# 150  1.859335e+10      Australia            AUS    1964  2.378766e+10
# 151  1.859335e+10      Australia            AUS    1964  2.378766e+10
#
#                               Name Sex   Age  Height  Weight  NOC  Season  \
# 0                Mohammad Ebrahimi   M  26.0   160.0    63.0  AFG  Summer
# 1           Faiz Mohammad Khakshar   M  22.0   162.0    52.0  AFG  Summer
# 149          Michael H. G. Ah Matt   M  21.0   188.0    73.0  AUS  Summer
# 150  Ian Graeme Keith "Mick" Allen   M  26.0   190.0    84.0  AUS  Summer
# 151     Edward James "Ted" Allsopp   M  38.0   179.0    80.0  AUS  Summer
#
#       City       Sport                                     Event Medal  \
# 0    Tokyo   Wrestling  Wrestling Men's Featherweight, Freestyle   DNW
# 1    Tokyo   Wrestling      Wrestling Men's Flyweight, Freestyle   DNW
# 149  Tokyo  Basketball               Basketball Men's Basketball   DNW
# 150  Tokyo      Rowing                  Rowing Men's Coxed Fours   DNW
# 151  Tokyo   Athletics        Athletics Men's 50 kilometres Walk   DNW
#
#      Determining Year
# 0                1960
# 1                1960
# 149              1960
# 150              1960
# 151              1960

# %%
determineDF.shape
# Out:
# (127891, 17)

# %%
determineDF.reset_index(drop=True).head(3)
# Out:
#           GDP_x Country Name_y Country Code_y  Year_y         GDP_y  \
# 0  5.377778e+08    Afghanistan            AFG    1964  8.000000e+08
# 1  5.377778e+08    Afghanistan            AFG    1964  8.000000e+08
# 2  1.859335e+10      Australia            AUS    1964  2.378766e+10
#
#                      Name Sex   Age  Height  Weight  NOC  Season   City  \
# 0       Mohammad Ebrahimi   M  26.0   160.0    63.0  AFG  Summer  Tokyo
# 1  Faiz Mohammad Khakshar   M  22.0   162.0    52.0  AFG  Summer  Tokyo
# 2   Michael H. G. Ah Matt   M  21.0   188.0    73.0  AUS  Summer  Tokyo
#
#         Sport                                     Event Medal  \
# 0   Wrestling  Wrestling Men's Featherweight, Freestyle   DNW
# 1   Wrestling      Wrestling Men's Flyweight, Freestyle   DNW
# 2  Basketball               Basketball Men's Basketball   DNW
#
#    Determining Year
# 0              1960
# 1              1960
# 2              1960

# %%
determineDF = determineDF.rename({'GDP_x': 'Games Year GDP', 'Country Name_y': 'Country', 'Country Code_y': 'Country Code','Year_y': 'Games Year', 'GDP_y':'Deter Year GDP'}, axis=1)

# %%
determineDF = determineDF[['Name', 'Country', 'Sex', 'Age', 'Weight', 'Height', 'Sport', 'Event', 'Medal', 'Games Year', 'Games Year GDP', 'Determining Year', 'Deter Year GDP', 'Season', 'City', 'NOC', 'Country Code']]
determineDF.head()
# Out:
#                               Name      Country Sex   Age  Weight  Height  \
# 0                Mohammad Ebrahimi  Afghanistan   M  26.0    63.0   160.0
# 1           Faiz Mohammad Khakshar  Afghanistan   M  22.0    52.0   162.0
# 149          Michael H. G. Ah Matt    Australia   M  21.0    73.0   188.0
# 150  Ian Graeme Keith "Mick" Allen    Australia   M  26.0    84.0   190.0
# 151     Edward James "Ted" Allsopp    Australia   M  38.0    80.0   179.0
#
#           Sport                                     Event Medal  Games Year  \
# 0     Wrestling  Wrestling Men's Featherweight, Freestyle   DNW        1964
# 1     Wrestling      Wrestling Men's Flyweight, Freestyle   DNW        1964
# 149  Basketball               Basketball Men's Basketball   DNW        1964
# 150      Rowing                  Rowing Men's Coxed Fours   DNW        1964
# 151   Athletics        Athletics Men's 50 kilometres Walk   DNW        1964
#
#      Games Year GDP  Determining Year  Deter Year GDP  Season   City  NOC  \
# 0      5.377778e+08              1960    8.000000e+08  Summer  Tokyo  AFG
# 1      5.377778e+08              1960    8.000000e+08  Summer  Tokyo  AFG
# 149    1.859335e+10              1960    2.378766e+10  Summer  Tokyo  AUS
# 150    1.859335e+10              1960    2.378766e+10  Summer  Tokyo  AUS
# 151    1.859335e+10              1960    2.378766e+10  Summer  Tokyo  AUS
#
#     Country Code
# 0            AFG
# 1            AFG
# 149          AUS
# 150          AUS
# 151          AUS

# %%
determineDF.reset_index(drop=True)
# Out:
#                                    Name      Country Sex   Age  Weight  \
# 0                     Mohammad Ebrahimi  Afghanistan   M  26.0    63.0
# 1                Faiz Mohammad Khakshar  Afghanistan   M  22.0    52.0
# 2                 Michael H. G. Ah Matt    Australia   M  21.0    73.0
# 3         Ian Graeme Keith "Mick" Allen    Australia   M  26.0    84.0
# 4            Edward James "Ted" Allsopp    Australia   M  38.0    80.0
# ...                                 ...          ...  ..   ...     ...
# 127886         Ivan Viktorovich Zaytsev   Uzbekistan   M  27.0    95.0
# 127887  Shakhobiddin Shokirovich Zoirov   Uzbekistan   M  23.0    52.0
# 127888       Nooran Ahmed Ali Ba Matraf  Yemen, Rep.   F  16.0    60.0
# 127889                      Zeyad Mater  Yemen, Rep.   M  24.0    73.0
# 127890                   Mohammed Rageh  Yemen, Rep.   M  18.0    64.0
#
#         Height       Sport                                     Event Medal  \
# 0        160.0   Wrestling  Wrestling Men's Featherweight, Freestyle   DNW
# 1        162.0   Wrestling      Wrestling Men's Flyweight, Freestyle   DNW
# 2        188.0  Basketball               Basketball Men's Basketball   DNW
# 3        190.0      Rowing                  Rowing Men's Coxed Fours   DNW
# 4        179.0   Athletics        Athletics Men's 50 kilometres Walk   DNW
# ...        ...         ...                                       ...   ...
# 127886   192.0   Athletics             Athletics Men's Javelin Throw   DNW
# 127887   169.0      Boxing                    Boxing Men's Flyweight  Gold
# 127888   166.0    Swimming     Swimming Women's 100 metres Butterfly   DNW
# 127889   174.0        Judo                    Judo Men's Lightweight   DNW
# 127890   169.0   Athletics              Athletics Men's 1,500 metres   DNW
#
#         Games Year  Games Year GDP  Determining Year  Deter Year GDP  Season  \
# 0             1964    5.377778e+08              1960    8.000000e+08  Summer
# 1             1964    5.377778e+08              1960    8.000000e+08  Summer
# 2             1964    1.859335e+10              1960    2.378766e+10  Summer
# 3             1964    1.859335e+10              1960    2.378766e+10  Summer
# 4             1964    1.859335e+10              1960    2.378766e+10  Summer
# ...            ...             ...               ...             ...     ...
# 127886        2016    5.182157e+10              2012    6.722034e+10  Summer
# 127887        2016    5.182157e+10              2012    6.722034e+10  Summer
# 127888        2016    3.539315e+10              2012    2.731761e+10  Summer
# 127889        2016    3.539315e+10              2012    2.731761e+10  Summer
# 127890        2016    3.539315e+10              2012    2.731761e+10  Summer
#
#                   City  NOC Country Code
# 0                Tokyo  AFG          AFG
# 1                Tokyo  AFG          AFG
# 2                Tokyo  AUS          AUS
# 3                Tokyo  AUS          AUS
# 4                Tokyo  AUS          AUS
# ...                ...  ...          ...
# 127886  Rio de Janeiro  UZB          UZB
# 127887  Rio de Janeiro  UZB          UZB
# 127888  Rio de Janeiro  YEM          YEM
# 127889  Rio de Janeiro  YEM          YEM
# 127890  Rio de Janeiro  YEM          YEM
#
# [127891 rows x 17 columns]

# %%
cols = list(determineDF.columns)
cols.remove('Name')
cols.remove('Country')
cols.remove('Sex')
cols.remove('Age')
cols.remove('Weight')
cols.remove('Height')
cols.remove('Sport')
cols.remove('Event')
cols.remove('Medal')
cols.remove('Games Year')
cols.remove('Determining Year')
cols.remove('Season')
cols.remove('City')
cols.remove('NOC')
cols.remove('Country Code')

# %%
determineDF[cols]
# Out:
#         Games Year GDP  Deter Year GDP
# 0         5.377778e+08    8.000000e+08
# 1         5.377778e+08    8.000000e+08
# 149       1.859335e+10    2.378766e+10
# 150       1.859335e+10    2.378766e+10
# 151       1.859335e+10    2.378766e+10
# ...                ...             ...
# 129620    5.182157e+10    6.722034e+10
# 129621    5.182157e+10    6.722034e+10
# 129622    3.539315e+10    2.731761e+10
# 129623    3.539315e+10    2.731761e+10
# 129624    3.539315e+10    2.731761e+10
#
# [127891 rows x 2 columns]

# %%
for col in cols:
    col_zscore = col + '_zscore'
    determineDF[col_zscore] = (determineDF[col] - determineDF[col].mean())/determineDF[col].std(ddof=0)
determineDF
# Out:
#                                    Name      Country Sex   Age  Weight  \
# 0                     Mohammad Ebrahimi  Afghanistan   M  26.0    63.0
# 1                Faiz Mohammad Khakshar  Afghanistan   M  22.0    52.0
# 149               Michael H. G. Ah Matt    Australia   M  21.0    73.0
# 150       Ian Graeme Keith "Mick" Allen    Australia   M  26.0    84.0
# 151          Edward James "Ted" Allsopp    Australia   M  38.0    80.0
# ...                                 ...          ...  ..   ...     ...
# 129620         Ivan Viktorovich Zaytsev   Uzbekistan   M  27.0    95.0
# 129621  Shakhobiddin Shokirovich Zoirov   Uzbekistan   M  23.0    52.0
# 129622       Nooran Ahmed Ali Ba Matraf  Yemen, Rep.   F  16.0    60.0
# 129623                      Zeyad Mater  Yemen, Rep.   M  24.0    73.0
# 129624                   Mohammed Rageh  Yemen, Rep.   M  18.0    64.0
#
#         Height       Sport                                     Event Medal  \
# 0        160.0   Wrestling  Wrestling Men's Featherweight, Freestyle   DNW
# 1        162.0   Wrestling      Wrestling Men's Flyweight, Freestyle   DNW
# 149      188.0  Basketball               Basketball Men's Basketball   DNW
# 150      190.0      Rowing                  Rowing Men's Coxed Fours   DNW
# 151      179.0   Athletics        Athletics Men's 50 kilometres Walk   DNW
# ...        ...         ...                                       ...   ...
# 129620   192.0   Athletics             Athletics Men's Javelin Throw   DNW
# 129621   169.0      Boxing                    Boxing Men's Flyweight  Gold
# 129622   166.0    Swimming     Swimming Women's 100 metres Butterfly   DNW
# 129623   174.0        Judo                    Judo Men's Lightweight   DNW
# 129624   169.0   Athletics              Athletics Men's 1,500 metres   DNW
#
#         Games Year  Games Year GDP  Determining Year  Deter Year GDP  Season  \
# 0             1964    5.377778e+08              1960    8.000000e+08  Summer
# 1             1964    5.377778e+08              1960    8.000000e+08  Summer
# 149           1964    1.859335e+10              1960    2.378766e+10  Summer
# 150           1964    1.859335e+10              1960    2.378766e+10  Summer
# 151           1964    1.859335e+10              1960    2.378766e+10  Summer
# ...            ...             ...               ...             ...     ...
# 129620        2016    5.182157e+10              2012    6.722034e+10  Summer
# 129621        2016    5.182157e+10              2012    6.722034e+10  Summer
# 129622        2016    3.539315e+10              2012    2.731761e+10  Summer
# 129623        2016    3.539315e+10              2012    2.731761e+10  Summer
# 129624        2016    3.539315e+10              2012    2.731761e+10  Summer
#
#                   City  NOC Country Code  Games Year GDP_zscore  \
# 0                Tokyo  AFG          AFG              -0.482547
# 1                Tokyo  AFG          AFG              -0.482547
# 149              Tokyo  AUS          AUS              -0.475742
# 150              Tokyo  AUS          AUS              -0.475742
# 151              Tokyo  AUS          AUS              -0.475742
# ...                ...  ...          ...                    ...
# 129620  Rio de Janeiro  UZB          UZB              -0.463220
# 129621  Rio de Janeiro  UZB          UZB              -0.463220
# 129622  Rio de Janeiro  YEM          YEM              -0.469411
# 129623  Rio de Janeiro  YEM          YEM              -0.469411
# 129624  Rio de Janeiro  YEM          YEM              -0.469411
#
#         Deter Year GDP_zscore
# 0                   -0.497700
# 1                   -0.497700
# 149                 -0.490351
# 150                 -0.490351
# 151                 -0.490351
# ...                       ...
# 129620              -0.476465
# 129621              -0.476465
# 129622              -0.489222
# 129623              -0.489222
# 129624              -0.489222
#
# [127891 rows x 19 columns]

# %%
determineDF.to_csv('athleteGDP.csv', sep=',')
