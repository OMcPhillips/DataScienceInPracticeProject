# %%
import networkx as nx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
athletes = pd.read_csv('athlete_events.csv')
athletes.shape
# Out:
# (271116, 15)

# %%
GDP = pd.read_excel('w_gdp.xls', skiprows=3)
GDP.shape
# Out:
# (219, 62)

# %%
GDP.drop(['Indicator Name', 'Indicator Code'], axis=1, inplace=True)

# %%
#new_header = GDP.iloc[2] 
#GDP = GDP[3:] 
#GDP.columns = new_header

# %%
GDP.head(3)
# Out:
#   Country Name Country Code          1960          1961          1962  \
# 0  Afghanistan          AFG  5.377778e+08  5.488889e+08  5.466667e+08
# 1      Albania          ALB           NaN           NaN           NaN
# 2      Algeria          DZA  2.723649e+09  2.434777e+09  2.001469e+09
#
#            1963          1964          1965          1966          1967  ...  \
# 0  7.511112e+08  8.000000e+08  1.006667e+09  1.400000e+09  1.673333e+09  ...
# 1           NaN           NaN           NaN           NaN           NaN  ...
# 2  2.703015e+09  2.909352e+09  3.136259e+09  3.039835e+09  3.370843e+09  ...
#
#            2008          2009          2010          2011          2012  \
# 0  1.019053e+10  1.248694e+10  1.593680e+10  1.793024e+10  2.053654e+10
# 1  1.288135e+10  1.204421e+10  1.192695e+10  1.289087e+10  1.231978e+10
# 2  1.710007e+11  1.372110e+11  1.612073e+11  2.000191e+11  2.090590e+11
#
#            2013          2014          2015          2016  2017
# 0  2.004633e+10  2.005019e+10  1.921556e+10  1.946902e+10   NaN
# 1  1.277628e+10  1.322824e+10  1.133526e+10  1.186387e+10   NaN
# 2  2.097550e+11  2.138100e+11  1.658743e+11  1.590491e+11   NaN
#
# [3 rows x 60 columns]

# %%
#GDP.reset_index(drop =True).head(3)

# %%
print (GDP.columns.tolist())
# Out:
# ['Country Name', 'Country Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017']

# %%
GDP = pd.melt(GDP, id_vars = ['Country Name', 'Country Code'], var_name = 'Year', value_name = 'GDP')

# %%
GDP['Year'] = pd.to_numeric(GDP['Year'])

# %%
GDP.head(10)
# Out:
#           Country Name Country Code  Year           GDP
# 0          Afghanistan          AFG  1960  5.377778e+08
# 1              Albania          ALB  1960           NaN
# 2              Algeria          DZA  1960  2.723649e+09
# 3       American Samoa          ASM  1960           NaN
# 4              Andorra          AND  1960           NaN
# 5               Angola          AGO  1960           NaN
# 6  Antigua and Barbuda          ATG  1960           NaN
# 7            Argentina          ARG  1960           NaN
# 8              Armenia          ARM  1960           NaN
# 9                Aruba          ABW  1960           NaN

# %%
gdp = pd.merge(GDP, athletes, left_on = ['Country Code', 'Year'], right_on = ['NOC', 'Year'])

# %%
gdp.head(40)
# Out:
#    Country Name Country Code  Year           GDP      ID  \
# 0   Afghanistan          AFG  1960  5.377778e+08   29626
# 1   Afghanistan          AFG  1960  5.377778e+08   39922
# 2   Afghanistan          AFG  1960  5.377778e+08   43901
# 3   Afghanistan          AFG  1960  5.377778e+08   58364
# 4   Afghanistan          AFG  1960  5.377778e+08   59043
# 5   Afghanistan          AFG  1960  5.377778e+08   59102
# 6   Afghanistan          AFG  1960  5.377778e+08   59346
# 7   Afghanistan          AFG  1960  5.377778e+08  106372
# 8   Afghanistan          AFG  1960  5.377778e+08  106372
# 9   Afghanistan          AFG  1960  5.377778e+08  109486
# 10  Afghanistan          AFG  1960  5.377778e+08  109486
# 11  Afghanistan          AFG  1960  5.377778e+08  116125
# 12  Afghanistan          AFG  1960  5.377778e+08  128736
# 13  Afghanistan          AFG  1960  5.377778e+08  128736
# 14  Afghanistan          AFG  1960  5.377778e+08  133717
# 15  Afghanistan          AFG  1960  5.377778e+08  133717
# 16    Argentina          ARG  1960           NaN     712
# 17    Argentina          ARG  1960           NaN    3660
# 18    Argentina          ARG  1960           NaN    3660
# 19    Argentina          ARG  1960           NaN    3660
# 20    Argentina          ARG  1960           NaN    4822
# 21    Argentina          ARG  1960           NaN    5133
# 22    Argentina          ARG  1960           NaN    5133
# 23    Argentina          ARG  1960           NaN    5246
# 24    Argentina          ARG  1960           NaN    7244
# 25    Argentina          ARG  1960           NaN    8842
# 26    Argentina          ARG  1960           NaN    8842
# 27    Argentina          ARG  1960           NaN   11483
# 28    Argentina          ARG  1960           NaN   12139
# 29    Argentina          ARG  1960           NaN   13093
# 30    Argentina          ARG  1960           NaN   13164
# 31    Argentina          ARG  1960           NaN   13863
# 32    Argentina          ARG  1960           NaN   15427
# 33    Argentina          ARG  1960           NaN   17428
# 34    Argentina          ARG  1960           NaN   17902
# 35    Argentina          ARG  1960           NaN   18414
# 36    Argentina          ARG  1960           NaN   19116
# 37    Argentina          ARG  1960           NaN   19164
# 38    Argentina          ARG  1960           NaN   19164
# 39    Argentina          ARG  1960           NaN   19164
#
#                            Name Sex   Age  Height  Weight         Team  NOC  \
# 0          Sultan Mohammad Dost   M  28.0   168.0    73.0  Afghanistan  AFG
# 1         Abdul Ghafar Ghafoori   M  22.0   172.0    70.0  Afghanistan  AFG
# 2         Ghulam Mohiddin Gunga   M  26.0   168.0    81.0  Afghanistan  AFG
# 3       Mohammad Ibrahim Kederi   M  20.0   166.0    62.0  Afghanistan  AFG
# 4        Faiz Mohammad Khakshar   M  18.0   162.0    52.0  Afghanistan  AFG
# 5            Amir Jan Khalunder   M  35.0   166.0    66.0  Afghanistan  AFG
# 6          Mohammad Asif Khokan   M  24.0   171.0    78.0  Afghanistan  AFG
# 7            Habib Zareef Sayed   M  23.0   170.0    58.0  Afghanistan  AFG
# 8            Habib Zareef Sayed   M  23.0   170.0    58.0  Afghanistan  AFG
# 9            Abdul Hadi Shekaib   M  20.0   178.0    68.0  Afghanistan  AFG
# 10           Abdul Hadi Shekaib   M  20.0   178.0    68.0  Afghanistan  AFG
# 11         Nizam-ud-din Subhani   M  34.0   168.0   111.0  Afghanistan  AFG
# 12           Abdul Hakim Wardak   M  20.0   179.0    75.0  Afghanistan  AFG
# 13           Abdul Hakim Wardak   M  20.0   179.0    75.0  Afghanistan  AFG
# 14       Ali Ahmed Youssef Zaid   M  20.0   168.0    58.0  Afghanistan  AFG
# 15       Ali Ahmed Youssef Zaid   M  20.0   168.0    58.0  Afghanistan  AFG
# 16              Hctor H. Acosta   M  26.0   180.0    81.0    Argentina  ARG
# 17           Osvaldo A. Ancinas   M  25.0     NaN     NaN    Argentina  ARG
# 18           Osvaldo A. Ancinas   M  25.0     NaN     NaN    Argentina  ARG
# 19           Osvaldo A. Ancinas   M  25.0     NaN     NaN    Argentina  ARG
# 20             Luis Ramn Aranda   M  23.0   175.0    57.0    Argentina  ARG
# 21                Pedro Armella   M  30.0   170.0    78.0    Argentina  ARG
# 22                Pedro Armella   M  30.0   170.0    78.0    Argentina  ARG
# 23           Carlos Alberto Aro   M  20.0   172.0    57.0    Argentina  ARG
# 24    Alberto Balestrini Bogino   M  29.0   168.0    61.0    Argentina  ARG
# 25                    Ral Bauza   M  25.0   180.0    73.0    Argentina  ARG
# 26                    Ral Bauza   M  25.0   180.0    73.0    Argentina  ARG
# 27      Carlos Salvador Bilardo   M  21.0   174.0    63.0    Argentina  ARG
# 28               Roberto Blanco   M  21.0   168.0    66.0    Argentina  ARG
# 29              Roberto Bonanno   M  22.0   172.0    72.0    Argentina  ARG
# 30  Ricardo Manuel Boneo Campos   M  29.0   172.0    65.0    Argentina  ARG
# 31            Miguel ngel Botta   M  19.0   163.0    51.0    Argentina  ARG
# 32                  Juan Brotto   M  20.0   183.0    79.0    Argentina  ARG
# 33           Hctor O. Calegaris   M  45.0   175.0    75.0        Tango  ARG
# 34            Carlos Rubn Caete   M  20.0   170.0    54.0    Argentina  ARG
# 35            Alfredo Carnovali   M  23.0   190.0    95.0    Argentina  ARG
# 36            Osvaldo Cavagnaro   M  22.0   180.0    78.0    Argentina  ARG
# 37     Juan Nicolas L. Caviglia   M  30.0   164.0    62.0    Argentina  ARG
# 38     Juan Nicolas L. Caviglia   M  30.0   164.0    62.0    Argentina  ARG
# 39     Juan Nicolas L. Caviglia   M  30.0   164.0    62.0    Argentina  ARG
#
#           Games  Season          City              Sport  \
# 0   1960 Summer  Summer          Roma          Wrestling
# 1   1960 Summer  Summer          Roma          Athletics
# 2   1960 Summer  Summer          Roma          Wrestling
# 3   1960 Summer  Summer          Roma          Wrestling
# 4   1960 Summer  Summer          Roma          Wrestling
# 5   1960 Summer  Summer          Roma          Wrestling
# 6   1960 Summer  Summer          Roma          Wrestling
# 7   1960 Summer  Summer          Roma          Athletics
# 8   1960 Summer  Summer          Roma          Athletics
# 9   1960 Summer  Summer          Roma          Athletics
# 10  1960 Summer  Summer          Roma          Athletics
# 11  1960 Summer  Summer          Roma          Wrestling
# 12  1960 Summer  Summer          Roma          Athletics
# 13  1960 Summer  Summer          Roma          Athletics
# 14  1960 Summer  Summer          Roma          Athletics
# 15  1960 Summer  Summer          Roma          Athletics
# 16  1960 Summer  Summer          Roma            Cycling
# 17  1960 Winter  Winter  Squaw Valley      Alpine Skiing
# 18  1960 Winter  Winter  Squaw Valley      Alpine Skiing
# 19  1960 Winter  Winter  Squaw Valley      Alpine Skiing
# 20  1960 Summer  Summer          Roma             Boxing
# 21  1960 Summer  Summer          Roma           Shooting
# 22  1960 Summer  Summer          Roma           Shooting
# 23  1960 Summer  Summer          Roma             Boxing
# 24  1960 Summer  Summer          Roma            Fencing
# 25  1960 Summer  Summer          Roma  Modern Pentathlon
# 26  1960 Summer  Summer          Roma  Modern Pentathlon
# 27  1960 Summer  Summer          Roma           Football
# 28  1960 Summer  Summer          Roma           Football
# 29  1960 Summer  Summer          Roma           Football
# 30  1960 Summer  Summer          Roma            Sailing
# 31  1960 Summer  Summer          Roma             Boxing
# 32  1960 Summer  Summer          Roma            Cycling
# 33  1960 Summer  Summer          Roma            Sailing
# 34  1960 Summer  Summer          Roma             Boxing
# 35  1960 Summer  Summer          Roma         Water Polo
# 36  1960 Summer  Summer          Roma             Rowing
# 37  1960 Summer  Summer          Roma         Gymnastics
# 38  1960 Summer  Summer          Roma         Gymnastics
# 39  1960 Summer  Summer          Roma         Gymnastics
#
#                                                 Event   Medal
# 0             Wrestling Men's Welterweight, Freestyle     NaN
# 1                Athletics Men's 4 x 100 metres Relay     NaN
# 2        Wrestling Men's Light-Heavyweight, Freestyle     NaN
# 3            Wrestling Men's Featherweight, Freestyle     NaN
# 4                Wrestling Men's Flyweight, Freestyle     NaN
# 5              Wrestling Men's Lightweight, Freestyle     NaN
# 6             Wrestling Men's Middleweight, Freestyle     NaN
# 7                          Athletics Men's 400 metres     NaN
# 8                Athletics Men's 4 x 100 metres Relay     NaN
# 9                          Athletics Men's 100 metres     NaN
# 10               Athletics Men's 4 x 100 metres Relay     NaN
# 11             Wrestling Men's Heavyweight, Freestyle     NaN
# 12                 Athletics Men's 110 metres Hurdles     NaN
# 13                      Athletics Men's Javelin Throw     NaN
# 14                         Athletics Men's 200 metres     NaN
# 15               Athletics Men's 4 x 100 metres Relay     NaN
# 16           Cycling Men's Team Pursuit, 4,000 metres     NaN
# 17                       Alpine Skiing Men's Downhill     NaN
# 18                   Alpine Skiing Men's Giant Slalom     NaN
# 19                         Alpine Skiing Men's Slalom     NaN
# 20                    Boxing Men's Light-Welterweight     NaN
# 21  Shooting Men's Free Rifle, Three Positions, 30...     NaN
# 22  Shooting Men's Small-Bore Rifle, Three Positio...     NaN
# 23                         Boxing Men's Featherweight     NaN
# 24                     Fencing Men's epee, Individual     NaN
# 25                 Modern Pentathlon Men's Individual     NaN
# 26                       Modern Pentathlon Men's Team     NaN
# 27                            Football Men's Football     NaN
# 28                            Football Men's Football     NaN
# 29                            Football Men's Football     NaN
# 30                    Sailing Mixed One Person Dinghy     NaN
# 31                             Boxing Men's Flyweight     NaN
# 32           Cycling Men's Team Pursuit, 4,000 metres     NaN
# 33                Sailing Mixed Three Person Keelboat  Silver
# 34                          Boxing Men's Bantamweight     NaN
# 35                        Water Polo Men's Water Polo     NaN
# 36                           Rowing Men's Coxed Pairs     NaN
# 37             Gymnastics Men's Individual All-Around     NaN
# 38                    Gymnastics Men's Floor Exercise     NaN
# 39                       Gymnastics Men's Horse Vault     NaN

# %%
gdp[gdp['Country Name'].str.contains("Ireland")]
# Out:
#        Country Name Country Code  Year           GDP      ID  \
# 2385        Ireland          IRL  1960  1.939330e+09    5172
# 2386        Ireland          IRL  1960  1.939330e+09   10223
# 2387        Ireland          IRL  1960  1.939330e+09   12144
# 2388        Ireland          IRL  1960  1.939330e+09   12144
# 2389        Ireland          IRL  1960  1.939330e+09   17635
# ...             ...          ...   ...           ...     ...
# 146000      Ireland          IRL  2016  3.048190e+11  121755
# 146001      Ireland          IRL  2016  3.048190e+11  128718
# 146002      Ireland          IRL  2016  3.048190e+11  128995
# 146003      Ireland          IRL  2016  3.048190e+11  131682
# 146004      Ireland          IRL  2016  3.048190e+11  131682
#
#                                     Name Sex   Age  Height  Weight     Team  \
# 2385                   Shirley Armstrong   F  30.0   167.0    52.0  Ireland
# 2386               Robert "Robin" Benson   M  31.0   177.0    79.0   Aletta
# 2387    Frances Christopher Buchan Bland   M  22.0   182.0    70.0  Ireland
# 2388    Frances Christopher Buchan Bland   M  22.0   182.0    70.0  Ireland
# 2389              Anthony "Tony" Cameron   M  29.0   175.0    61.0  Ireland
# ...                                  ...  ..   ...     ...     ...      ...
# 146000                Sara Louise Treacy   F  27.0   168.0    58.0  Ireland
# 146001                 Joseph "Joe" Ward   M  22.0   186.0    81.0  Ireland
# 146002                      Michael Watt   M  29.0   178.0    79.0  Ireland
# 146003                       Alex Wright   M  25.0   175.0    62.0  Ireland
# 146004                       Alex Wright   M  25.0   175.0    62.0  Ireland
#
#         NOC        Games  Season            City          Sport  \
# 2385    IRL  1960 Summer  Summer            Roma        Fencing
# 2386    IRL  1960 Summer  Summer            Roma        Sailing
# 2387    IRL  1960 Summer  Summer            Roma        Fencing
# 2388    IRL  1960 Summer  Summer            Roma        Fencing
# 2389    IRL  1960 Summer  Summer            Roma  Equestrianism
# ...     ...          ...     ...             ...            ...
# 146000  IRL  2016 Summer  Summer  Rio de Janeiro      Athletics
# 146001  IRL  2016 Summer  Summer  Rio de Janeiro         Boxing
# 146002  IRL  2016 Summer  Summer  Rio de Janeiro         Hockey
# 146003  IRL  2016 Summer  Summer  Rio de Janeiro      Athletics
# 146004  IRL  2016 Summer  Summer  Rio de Janeiro      Athletics
#
#                                                   Event Medal
# 2385                   Fencing Women's Foil, Individual   NaN
# 2386                Sailing Mixed Three Person Keelboat   NaN
# 2387                     Fencing Men's epee, Individual   NaN
# 2388                           Fencing Men's epee, Team   NaN
# 2389    Equestrianism Men's Three-Day Event, Individual   NaN
# ...                                                 ...   ...
# 146000      Athletics Women's 3,000 metres Steeplechase   NaN
# 146001                   Boxing Men's Light-Heavyweight   NaN
# 146002                              Hockey Men's Hockey   NaN
# 146003               Athletics Men's 20 kilometres Walk   NaN
# 146004               Athletics Men's 50 kilometres Walk   NaN
#
# [1070 rows x 18 columns]

# %%
city = athletes['City'] == 'Beijing'
athletes[city].head(3)
athletes[city].shape
# Out:
# (13602, 15)

# %%
gdp.to_csv('athleteGDP.csv', sep=',')
